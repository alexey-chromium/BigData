# %% [markdown]
# # Лабораторная 2. Формирование отчётов в Apache Spark
#
# ## Задание
#
# Сформировать отчёт с информацией о 10 наиболее популярных языках программирования по итогам года за период с 2010 по 2020 годы. Отчёт будет отражать динамику изменения популярности языков программирования и представлять собой набор таблиц "топ-10" для каждого года.
#
# Получившийся отчёт сохранить в формате Apache Parquet.
#
# Для выполнения задания вы можете использовать любую комбинацию Spark API: RDD API, Dataset API, SQL API.

# %% [markdown]
# ## 1. Установка PySpark

# %%
# !pip install -q pyspark==3.5.1

# %% [markdown]
# ## 2. Подключение Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## 3. Пути к файлам

# %%
BASE_PATH = "/content/drive/MyDrive/BD_LR"

POSTS_PATH = f"{BASE_PATH}/posts_sample.xml"
LANGUAGES_PATH = f"{BASE_PATH}/programming-languages.csv"
OUTPUT_PATH = f"{BASE_PATH}/top_languages_2010_2020.parquet"

print("POSTS_PATH =", POSTS_PATH)
print("LANGUAGES_PATH =", LANGUAGES_PATH)
print("OUTPUT_PATH =", OUTPUT_PATH)
# Out:
# POSTS_PATH = /content/drive/MyDrive/BD_LR/posts_sample.xml
# LANGUAGES_PATH = /content/drive/MyDrive/BD_LR/programming-languages.csv
# OUTPUT_PATH = /content/drive/MyDrive/BD_LR/top_languages_2010_2020.parquet

# %% [markdown]
# ## 4. Импорты и создание SparkSession

# %%
import re
from pyspark.sql import SparkSession, functions as F, Window

spark = (
    SparkSession.builder
    .appName("Top programming languages 2010-2020")
    .master("local[*]")
    .config("spark.sql.session.timeZone", "UTC")
    .config("spark.jars.packages", "com.databricks:spark-xml_2.12:0.18.0")
    .getOrCreate()
)

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://a72b9e617e69:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Top programming languages 2010-2020</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## 5. Функция нормализации названий языков
#
# Она приводит названия из CSV к виду тегов Stack Overflow.

# %%
def normalize_language_to_tag(name: str):
    if name is None:
        return None

    s = name.strip().lower()
    if not s:
        return None

    # убираем содержимое в скобках
    s = re.sub(r"\s*\(.*?\)\s*", " ", s)

    # убираем хвосты вида " - ISO/IEC ..." или " – ISO/IEC ..."
    s = re.sub(r"\s*[–—-]\s*iso.*$", "", s)

    # убираем хвосты после запятой
    s = re.sub(r"\s*,.*$", "", s)

    # нормализуем пробелы
    s = re.sub(r"\s+", " ", s).strip()

    aliases = {
        "visual basic .net": "vb.net",
        "visual basic": "visual-basic",
        "objective c": "objective-c",
        "common lisp": "common-lisp",
        "assembly language": "assembly",
        "emacs lisp": "elisp",
        "wolfram language": "mathematica",
        "go!": "go",
    }

    if s in aliases:
        return aliases[s]

    return s.replace(" ", "-")

# %% [markdown]
# ## 6. Чтение XML с постами

# %%
posts = (
    spark.read
    .format("xml")
    .option("rowTag", "row")
    .load(POSTS_PATH)
    .select(
        F.col("_Id").alias("post_id"),
        F.col("_PostTypeId").cast("int").alias("post_type_id"),
        F.col("_CreationDate").alias("creation_date"),
        F.col("_Tags").alias("tags")
    )
)

posts.show(10, truncate=False)
posts.printSchema()
# Out:
# +-------+------------+-----------------------+------------------------------------------------------+
# |post_id|post_type_id|creation_date          |tags                                                  |
# +-------+------------+-----------------------+------------------------------------------------------+
# |4      |1           |2008-07-31 21:42:52.667|<c#><floating-point><type-conversion><double><decimal>|
# |6      |1           |2008-07-31 22:08:08.62 |<html><css><internet-explorer-7>                      |
# |7      |2           |2008-07-31 22:17:57.883|NULL                                                  |
# |9      |1           |2008-07-31 23:40:59.743|<c#><.net><datetime>                                  |
# |11     |1           |2008-07-31 23:55:37.967|<c#><datetime><time><datediff><relative-time-span>    |
# |12     |2           |2008-07-31 23:56:41.303|NULL                                                  |
# |13     |1           |2008-08-01 00:42:38.903|<html><browser><timezone><user-agent><timezone-offset>|
# |14     |1           |2008-08-01 00:59:11.177|<.net><math>                                          |
# |3753373|2           |2010-09-20 16:18:14.58 |NULL                                                  |
# |3754384|2           |2010-09-20 18:36:28.023|NULL                                                  |
# +-------+------------+-----------------------+------------------------------------------------------+
# only showing top 10 rows
#
# root
#  |-- post_id: long (nullable = true)
#  |-- post_type_id: integer (nullable = true)
#  |-- creation_date: timestamp (nullable = true)
#  |-- tags: string (nullable = true)

# %% [markdown]
# ## 7. Чтение CSV со списком языков

# %%
languages_raw = (
    spark.read
    .option("header", True)
    .option("multiLine", True)
    .csv(LANGUAGES_PATH)
)

languages_raw.show(10, truncate=False)
print(languages_raw.columns)
# Out:
# +----------+---------------------------------------------------------+
# |name      |wikipedia_url                                            |
# +----------+---------------------------------------------------------+
# |A# .NET   |https://en.wikipedia.org/wiki/A_Sharp_(.NET)             |
# |A# (Axiom)|https://en.wikipedia.org/wiki/A_Sharp_(Axiom)            |
# |A-0 System|https://en.wikipedia.org/wiki/A-0_System                 |
# |A+        |https://en.wikipedia.org/wiki/A%2B_(programming_language)|
# |A++       |https://en.wikipedia.org/wiki/A%2B%2B                    |
# |ABAP      |https://en.wikipedia.org/wiki/ABAP                       |
# |ABC       |https://en.wikipedia.org/wiki/ABC_(programming_language) |
# |ABC ALGOL |https://en.wikipedia.org/wiki/ABC_ALGOL                  |
# |ABSET     |https://en.wikipedia.org/wiki/ABSET                      |
# |ABSYS     |https://en.wikipedia.org/wiki/ABSYS                      |
# +----------+---------------------------------------------------------+
# only showing top 10 rows
#
# ['name', 'wikipedia_url']

# %% [markdown]
# ## 8. Подготовка справочника языков

# %%
possible_cols = [
    c for c in languages_raw.columns
    if c.lower() in {"name", "language", "programming_language"}
]

language_col = possible_cols[0] if possible_cols else languages_raw.columns[0]

language_names = [
    row[0]
    for row in languages_raw.select(F.col(language_col)).distinct().collect()
    if row[0] is not None
]

tag_to_language = {}

for lang in language_names:
    tag = normalize_language_to_tag(lang)
    if tag and tag not in tag_to_language:
        tag_to_language[tag] = lang.strip()

languages_df = spark.createDataFrame(
    [(tag, display) for tag, display in tag_to_language.items()],
    ["tag", "language"]
)

languages_df.orderBy("language").show(30, truncate=False)
print("Количество языков после нормализации:", languages_df.count())
# Out:
# +------------+------------+
# |tag         |language    |
# +------------+------------+
# |@formula    |@Formula    |
# |a#          |A# (Axiom)  |
# |a#-.net     |A# .NET     |
# |a+          |A+          |
# |a++         |A++         |
# |a-0-system  |A-0 System  |
# |abap        |ABAP        |
# |abc         |ABC         |
# |abc-algol   |ABC ALGOL   |
# |abset       |ABSET       |
# |absys       |ABSYS       |
# |acc         |ACC         |
# |acl2        |ACL2        |
# |act-iii     |ACT-III     |
# |aimms       |AIMMS       |
# |alf         |ALF         |
# |algol-58    |ALGOL 58    |
# |algol-60    |ALGOL 60    |
# |algol-68    |ALGOL 68    |
# |algol-w     |ALGOL W     |
# |amos        |AMOS        |
# |ampl        |AMPL        |
# |apl         |APL         |
# |arexx       |ARexx       |
# |ats         |ATS         |
# |awk         |AWK         |
# |accent      |Accent      |
# |ace-dasl    |Ace DASL    |
# |action!     |Action!     |
# |actionscript|ActionScript|
# +------------+------------+
# only showing top 30 rows
#
# Количество языков после нормализации: 692

# %% [markdown]
# ## 9. Отбор только вопросов за 2010–2020 годы

# %%
questions = (
    posts
    .filter(F.col("post_type_id") == 1)          # только вопросы
    .filter(F.col("tags").isNotNull())
    .filter(F.col("creation_date").isNotNull())
    .withColumn("creation_ts", F.to_timestamp("creation_date"))
    .withColumn("year", F.year("creation_ts"))
    .filter((F.col("year") >= 2010) & (F.col("year") <= 2020))
)

questions.select("post_id", "year", "tags").show(20, truncate=False)
print("Количество вопросов за 2010-2020:", questions.count())
# Out:
# +-------+----+---------------------------------------------------------------+
# |post_id|year|tags                                                           |
# +-------+----+---------------------------------------------------------------+
# |3768363|2010|<c++><character-encoding>                                      |
# |3775996|2010|<sharepoint><infopath>                                         |
# |3776721|2010|<iphone><app-store><in-app-purchase>                           |
# |3777993|2010|<symfony1><schema><doctrine><fixtures>                         |
# |3778222|2010|<java>                                                         |
# |3785460|2010|<visual-studio-2010><stylecop>                                 |
# |3789116|2010|<cakephp><file-upload><swfupload>                              |
# |3794815|2010|<git><cygwin><putty>                                           |
# |3797876|2010|<drupal><drupal-6>                                             |
# |3798872|2010|<php><wordpress><memory>                                       |
# |3801290|2010|<c#><winforms><data-binding><checkedlistbox>                   |
# |3802658|2010|<c#><asp.net><exception-handling>                              |
# |3811129|2010|<sql><xml><blob>                                               |
# |3816031|2010|<.htaccess><codeigniter>                                       |
# |3821203|2010|<wcf><web-services><anonymous><basichttpbinding><wshttpbinding>|
# |3823026|2010|<mod-rewrite><apache2>                                         |
# |3824347|2010|<sql><database><default><sybase>                               |
# |3833655|2010|<ruby><rvm>                                                    |
# |3834741|2010|<android><eclipse>                                             |
# |3836216|2010|<iphone><uiimageview><pinch><image-zoom>                       |
# +-------+----+---------------------------------------------------------------+
# only showing top 20 rows
#
# Количество вопросов за 2010-2020: 17642

# %% [markdown]
# ## 10. Разбор тегов

# %%
question_tags = (
    questions
    .withColumn(
        "tag_array",
        F.split(
            F.regexp_replace(
                F.regexp_replace(F.col("tags"), r"^<|>$", ""),
                r"><",
                "|"
            ),
            r"\|"
        )
    )
    .select(
        "post_id",
        "year",
        F.explode("tag_array").alias("tag")
    )
    .withColumn("tag", F.lower(F.col("tag")))
)

question_tags.show(30, truncate=False)
# Out:
# +-------+----+------------------+
# |post_id|year|tag               |
# +-------+----+------------------+
# |3768363|2010|c++               |
# |3768363|2010|character-encoding|
# |3775996|2010|sharepoint        |
# |3775996|2010|infopath          |
# |3776721|2010|iphone            |
# |3776721|2010|app-store         |
# |3776721|2010|in-app-purchase   |
# |3777993|2010|symfony1          |
# |3777993|2010|schema            |
# |3777993|2010|doctrine          |
# |3777993|2010|fixtures          |
# |3778222|2010|java              |
# |3785460|2010|visual-studio-2010|
# |3785460|2010|stylecop          |
# |3789116|2010|cakephp           |
# |3789116|2010|file-upload       |
# |3789116|2010|swfupload         |
# |3794815|2010|git               |
# |3794815|2010|cygwin            |
# |3794815|2010|putty             |
# |3797876|2010|drupal            |
# |3797876|2010|drupal-6          |
# |3798872|2010|php               |
# |3798872|2010|wordpress         |
# |3798872|2010|memory            |
# |3801290|2010|c#                |
# |3801290|2010|winforms          |
# |3801290|2010|data-binding      |
# |3801290|2010|checkedlistbox    |
# |3802658|2010|c#                |
# +-------+----+------------------+
# only showing top 30 rows

# %% [markdown]
# ## 11. Оставляем только теги, которые являются языками программирования

# %%
language_questions = (
    question_tags
    .join(F.broadcast(languages_df), on="tag", how="inner")
)

language_questions.show(30, truncate=False)
print("Количество совпадений тегов с языками:", language_questions.count())
# Out:
# +-----------+-------+----+-------------------+
# |tag        |post_id|year|language           |
# +-----------+-------+----+-------------------+
# |c++        |3768363|2010|C++ – ISO/IEC 14882|
# |java       |3778222|2010|Java               |
# |php        |3798872|2010|PHP                |
# |c#         |3801290|2010|C# – ISO/IEC 23270 |
# |c#         |3802658|2010|C# – ISO/IEC 23270 |
# |ruby       |3833655|2010|Ruby               |
# |c          |3838866|2010|C                  |
# |c#         |3841866|2010|C# – ISO/IEC 23270 |
# |c#         |3858524|2010|C# – ISO/IEC 23270 |
# |php        |3859099|2010|PHP                |
# |python     |3872977|2010|Python             |
# |javascript |3885802|2010|JavaScript         |
# |applescript|3886770|2010|AppleScript        |
# |c#         |3890854|2010|C# – ISO/IEC 23270 |
# |php        |3891676|2010|PHP                |
# |c++        |3901256|2010|C++ – ISO/IEC 14882|
# |php        |3904423|2010|PHP                |
# |c#         |3914572|2010|C# – ISO/IEC 23270 |
# |javascript |3914572|2010|JavaScript         |
# |sed        |3916495|2010|Sed                |
# |python     |3918385|2010|Python             |
# |c#         |3933281|2010|C# – ISO/IEC 23270 |
# |c#         |3950937|2010|C# – ISO/IEC 23270 |
# |java       |3950937|2010|Java               |
# |c++        |3950937|2010|C++ – ISO/IEC 14882|
# |ruby       |3950937|2010|Ruby               |
# |objective-c|3952720|2010|Objective-C        |
# |javascript |3953705|2010|JavaScript         |
# |r          |3955878|2010|R                  |
# |c++        |3956798|2010|C++ – ISO/IEC 14882|
# +-----------+-------+----+-------------------+
# only showing top 30 rows
#
# Количество совпадений тегов с языками: 10275

# %% [markdown]
# ## 12. Подсчёт количества вопросов по паре (год, язык)

# %%
yearly_counts = (
    language_questions
    .groupBy("year", "language")
    .agg(F.countDistinct("post_id").alias("question_count"))
)

yearly_counts.orderBy("year", F.desc("question_count"), "language").show(50, truncate=False)
# Out:
# +----+-------------------------------------------------+--------------+
# |year|language                                         |question_count|
# +----+-------------------------------------------------+--------------+
# |2010|C# – ISO/IEC 23270                               |96            |
# |2010|Java                                             |52            |
# |2010|PHP                                              |46            |
# |2010|JavaScript                                       |44            |
# |2010|C++ – ISO/IEC 14882                              |28            |
# |2010|Python                                           |26            |
# |2010|Objective-C                                      |23            |
# |2010|C                                                |20            |
# |2010|Ruby                                             |12            |
# |2010|Delphi                                           |8             |
# |2010|AppleScript                                      |3             |
# |2010|Bash                                             |3             |
# |2010|Perl                                             |3             |
# |2010|R                                                |3             |
# |2010|Assembly language                                |2             |
# |2010|F#                                               |2             |
# |2010|Haskell                                          |2             |
# |2010|Sed                                              |2             |
# |2010|ActionScript                                     |1             |
# |2010|BASIC                                            |1             |
# |2010|Go!                                              |1             |
# |2010|MATLAB                                           |1             |
# |2010|Max (Max Msp – Graphical Programming Environment)|1             |
# |2010|Mouse                                            |1             |
# |2010|OCaml                                            |1             |
# |2010|Pascal – ISO 7185                                |1             |
# |2010|PowerShell                                       |1             |
# |2010|Racket                                           |1             |
# |2010|Scala                                            |1             |
# |2010|Scheme                                           |1             |
# |2010|XPath                                            |1             |
# |2010|dBase                                            |1             |
# |2010|ksh                                              |1             |
# |2011|PHP                                              |102           |
# |2011|C# – ISO/IEC 23270                               |100           |
# |2011|Java                                             |93            |
# |2011|JavaScript                                       |83            |
# |2011|C++ – ISO/IEC 14882                              |42            |
# |2011|Python                                           |37            |
# |2011|Objective-C                                      |34            |
# |2011|C                                                |24            |
# |2011|Ruby                                             |20            |
# |2011|Perl                                             |9             |
# |2011|Delphi                                           |8             |
# |2011|Bash                                             |7             |
# |2011|MATLAB                                           |5             |
# |2011|ActionScript                                     |4             |
# |2011|ColdFusion                                       |4             |
# |2011|R                                                |3             |
# |2011|Scala                                            |3             |
# +----+-------------------------------------------------+--------------+
# only showing top 50 rows

# %% [markdown]
# ## 13. Построение top-10 языков для каждого года

# %%
w = Window.partitionBy("year").orderBy(
    F.desc("question_count"),
    F.asc("language")
)

result = (
    yearly_counts
    .withColumn("rank", F.row_number().over(w))
    .filter(F.col("rank") <= 10)
    .select("year", "rank", "language", "question_count")
    .orderBy("year", "rank")
)

result.show(200, truncate=False)
# Out:
# +----+----+-----------------------------------+--------------+
# |year|rank|language                           |question_count|
# +----+----+-----------------------------------+--------------+
# |2010|1   |C# – ISO/IEC 23270                 |96            |
# |2010|2   |Java                               |52            |
# |2010|3   |PHP                                |46            |
# |2010|4   |JavaScript                         |44            |
# |2010|5   |C++ – ISO/IEC 14882                |28            |
# |2010|6   |Python                             |26            |
# |2010|7   |Objective-C                        |23            |
# |2010|8   |C                                  |20            |
# |2010|9   |Ruby                               |12            |
# |2010|10  |Delphi                             |8             |
# |2011|1   |PHP                                |102           |
# |2011|2   |C# – ISO/IEC 23270                 |100           |
# |2011|3   |Java                               |93            |
# |2011|4   |JavaScript                         |83            |
# |2011|5   |C++ – ISO/IEC 14882                |42            |
# |2011|6   |Python                             |37            |
# |2011|7   |Objective-C                        |34            |
# |2011|8   |C                                  |24            |
# |2011|9   |Ruby                               |20            |
# |2011|10  |Perl                               |9             |
# |2012|1   |PHP                                |154           |
# |2012|2   |C# – ISO/IEC 23270                 |138           |
# |2012|3   |JavaScript                         |132           |
# |2012|4   |Java                               |124           |
# |2012|5   |C++ – ISO/IEC 14882                |81            |
# |2012|6   |Python                             |69            |
# |2012|7   |Objective-C                        |45            |
# |2012|8   |C                                  |27            |
# |2012|9   |Ruby                               |27            |
# |2012|10  |Bash                               |10            |
# |2013|1   |JavaScript                         |198           |
# |2013|2   |PHP                                |198           |
# |2013|3   |Java                               |194           |
# |2013|4   |C# – ISO/IEC 23270                 |172           |
# |2013|5   |Python                             |90            |
# |2013|6   |C++ – ISO/IEC 14882                |71            |
# |2013|7   |Objective-C                        |40            |
# |2013|8   |C                                  |36            |
# |2013|9   |Ruby                               |32            |
# |2013|10  |R                                  |26            |
# |2014|1   |JavaScript                         |239           |
# |2014|2   |Java                               |228           |
# |2014|3   |C# – ISO/IEC 23270                 |183           |
# |2014|4   |PHP                                |167           |
# |2014|5   |Python                             |109           |
# |2014|6   |C++ – ISO/IEC 14882                |77            |
# |2014|7   |C                                  |52            |
# |2014|8   |Objective-C                        |52            |
# |2014|9   |R                                  |28            |
# |2014|10  |Ruby                               |24            |
# |2015|1   |JavaScript                         |277           |
# |2015|2   |Java                               |209           |
# |2015|3   |PHP                                |167           |
# |2015|4   |C# – ISO/IEC 23270                 |155           |
# |2015|5   |Python                             |121           |
# |2015|6   |C++ – ISO/IEC 14882                |86            |
# |2015|7   |Swift (parallel scripting language)|57            |
# |2015|8   |R                                  |43            |
# |2015|9   |C                                  |38            |
# |2015|10  |Objective-C                        |30            |
# |2016|1   |JavaScript                         |278           |
# |2016|2   |Java                               |184           |
# |2016|3   |PHP                                |155           |
# |2016|4   |Python                             |146           |
# |2016|5   |C# – ISO/IEC 23270                 |136           |
# |2016|6   |C++ – ISO/IEC 14882                |72            |
# |2016|7   |R                                  |52            |
# |2016|8   |Swift (parallel scripting language)|52            |
# |2016|9   |C                                  |32            |
# |2016|10  |Ruby                               |24            |
# |2017|1   |JavaScript                         |246           |
# |2017|2   |Java                               |204           |
# |2017|3   |Python                             |193           |
# |2017|4   |PHP                                |138           |
# |2017|5   |C# – ISO/IEC 23270                 |127           |
# |2017|6   |C++ – ISO/IEC 14882                |72            |
# |2017|7   |R                                  |56            |
# |2017|8   |Swift (parallel scripting language)|28            |
# |2017|9   |C                                  |25            |
# |2017|10  |TypeScript                         |20            |
# |2018|1   |Python                             |220           |
# |2018|2   |JavaScript                         |198           |
# |2018|3   |Java                               |146           |
# |2018|4   |C# – ISO/IEC 23270                 |116           |
# |2018|5   |PHP                                |111           |
# |2018|6   |R                                  |66            |
# |2018|7   |C++ – ISO/IEC 14882                |53            |
# |2018|8   |Swift (parallel scripting language)|39            |
# |2018|9   |TypeScript                         |27            |
# |2018|10  |C                                  |24            |
# |2019|1   |Python                             |166           |
# |2019|2   |JavaScript                         |135           |
# |2019|3   |Java                               |95            |
# |2019|4   |C# – ISO/IEC 23270                 |73            |
# |2019|5   |PHP                                |65            |
# |2019|6   |R                                  |37            |
# |2019|7   |C++ – ISO/IEC 14882                |34            |
# |2019|8   |Swift (parallel scripting language)|24            |
# |2019|9   |TypeScript                         |17            |
# |2019|10  |C                                  |14            |
# +----+----+-----------------------------------+--------------+

# %% [markdown]
# ## 14. Сохранение результата в Apache Parquet

# %%
(
    result
    .write
    .mode("overwrite")
    .parquet(OUTPUT_PATH)
)

print("Результат сохранён в:", OUTPUT_PATH)
# Out:
# Результат сохранён в: /content/drive/MyDrive/BD_LR/top_languages_2010_2020.parquet

# %% [markdown]
# ## 15. Проверка сохранённого Parquet

# %%
saved_result = spark.read.parquet(OUTPUT_PATH)
saved_result.orderBy("year", "rank").show(200, truncate=False)
# Out:
# +----+----+-----------------------------------+--------------+
# |year|rank|language                           |question_count|
# +----+----+-----------------------------------+--------------+
# |2010|1   |C# – ISO/IEC 23270                 |96            |
# |2010|2   |Java                               |52            |
# |2010|3   |PHP                                |46            |
# |2010|4   |JavaScript                         |44            |
# |2010|5   |C++ – ISO/IEC 14882                |28            |
# |2010|6   |Python                             |26            |
# |2010|7   |Objective-C                        |23            |
# |2010|8   |C                                  |20            |
# |2010|9   |Ruby                               |12            |
# |2010|10  |Delphi                             |8             |
# |2011|1   |PHP                                |102           |
# |2011|2   |C# – ISO/IEC 23270                 |100           |
# |2011|3   |Java                               |93            |
# |2011|4   |JavaScript                         |83            |
# |2011|5   |C++ – ISO/IEC 14882                |42            |
# |2011|6   |Python                             |37            |
# |2011|7   |Objective-C                        |34            |
# |2011|8   |C                                  |24            |
# |2011|9   |Ruby                               |20            |
# |2011|10  |Perl                               |9             |
# |2012|1   |PHP                                |154           |
# |2012|2   |C# – ISO/IEC 23270                 |138           |
# |2012|3   |JavaScript                         |132           |
# |2012|4   |Java                               |124           |
# |2012|5   |C++ – ISO/IEC 14882                |81            |
# |2012|6   |Python                             |69            |
# |2012|7   |Objective-C                        |45            |
# |2012|8   |C                                  |27            |
# |2012|9   |Ruby                               |27            |
# |2012|10  |Bash                               |10            |
# |2013|1   |JavaScript                         |198           |
# |2013|2   |PHP                                |198           |
# |2013|3   |Java                               |194           |
# |2013|4   |C# – ISO/IEC 23270                 |172           |
# |2013|5   |Python                             |90            |
# |2013|6   |C++ – ISO/IEC 14882                |71            |
# |2013|7   |Objective-C                        |40            |
# |2013|8   |C                                  |36            |
# |2013|9   |Ruby                               |32            |
# |2013|10  |R                                  |26            |
# |2014|1   |JavaScript                         |239           |
# |2014|2   |Java                               |228           |
# |2014|3   |C# – ISO/IEC 23270                 |183           |
# |2014|4   |PHP                                |167           |
# |2014|5   |Python                             |109           |
# |2014|6   |C++ – ISO/IEC 14882                |77            |
# |2014|7   |C                                  |52            |
# |2014|8   |Objective-C                        |52            |
# |2014|9   |R                                  |28            |
# |2014|10  |Ruby                               |24            |
# |2015|1   |JavaScript                         |277           |
# |2015|2   |Java                               |209           |
# |2015|3   |PHP                                |167           |
# |2015|4   |C# – ISO/IEC 23270                 |155           |
# |2015|5   |Python                             |121           |
# |2015|6   |C++ – ISO/IEC 14882                |86            |
# |2015|7   |Swift (parallel scripting language)|57            |
# |2015|8   |R                                  |43            |
# |2015|9   |C                                  |38            |
# |2015|10  |Objective-C                        |30            |
# |2016|1   |JavaScript                         |278           |
# |2016|2   |Java                               |184           |
# |2016|3   |PHP                                |155           |
# |2016|4   |Python                             |146           |
# |2016|5   |C# – ISO/IEC 23270                 |136           |
# |2016|6   |C++ – ISO/IEC 14882                |72            |
# |2016|7   |R                                  |52            |
# |2016|8   |Swift (parallel scripting language)|52            |
# |2016|9   |C                                  |32            |
# |2016|10  |Ruby                               |24            |
# |2017|1   |JavaScript                         |246           |
# |2017|2   |Java                               |204           |
# |2017|3   |Python                             |193           |
# |2017|4   |PHP                                |138           |
# |2017|5   |C# – ISO/IEC 23270                 |127           |
# |2017|6   |C++ – ISO/IEC 14882                |72            |
# |2017|7   |R                                  |56            |
# |2017|8   |Swift (parallel scripting language)|28            |
# |2017|9   |C                                  |25            |
# |2017|10  |TypeScript                         |20            |
# |2018|1   |Python                             |220           |
# |2018|2   |JavaScript                         |198           |
# |2018|3   |Java                               |146           |
# |2018|4   |C# – ISO/IEC 23270                 |116           |
# |2018|5   |PHP                                |111           |
# |2018|6   |R                                  |66            |
# |2018|7   |C++ – ISO/IEC 14882                |53            |
# |2018|8   |Swift (parallel scripting language)|39            |
# |2018|9   |TypeScript                         |27            |
# |2018|10  |C                                  |24            |
# |2019|1   |Python                             |166           |
# |2019|2   |JavaScript                         |135           |
# |2019|3   |Java                               |95            |
# |2019|4   |C# – ISO/IEC 23270                 |73            |
# |2019|5   |PHP                                |65            |
# |2019|6   |R                                  |37            |
# |2019|7   |C++ – ISO/IEC 14882                |34            |
# |2019|8   |Swift (parallel scripting language)|24            |
# |2019|9   |TypeScript                         |17            |
# |2019|10  |C                                  |14            |
# +----+----+-----------------------------------+--------------+

# %% [markdown]
# ## 16. Завершение работы

# %%
spark.stop()
